# %% [markdown]
# <a href="https://colab.research.google.com/github/SEC-API-io/sec-api-cookbook/blob/main/notebooks/query-api/quick-start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Quick Start
#
# The example below demonstrates how to use the `sec-api` Python package to interact with the Query API. It shows how to retrieve metadata for the latest 50 EDGAR filings for Tesla using the `get_filings(search_parameters)` function from the `QueryApi` class. The search parameters are passed to the `get_filings` function and include:
#
# - `query`: The Lucene search query, such as `ticker:TSLA`.
# - `from`: The starting index for pagination of search results.
# - `size`: The number of results to return per request (maximum of 50).
# - `sort`: The field to sort the results by, defaulting to `filedAt` in descending order.
#
# Refer to the [documentation for more details on the API request format](https://sec-api.io/docs/query-api#request-format).

# %%
pip install sec-api

# %%
from sec_api import QueryApi

queryApi = QueryApi(api_key="YOUR_API_KEY")

search_params = {
    "query": "ticker:TSLA",
    "from": "0",
    "size": "50",
    "sort": [{"filedAt": {"order": "desc"}}],
}

response = queryApi.get_filings(search_params)

# %%
print("Response object fields:\n", list(response.keys()))
# Out:
# Response object fields:
#  ['total', 'query', 'filings']

# %%
print("Number of filings matching the search criteria:\n", response['total']['value'])
# Out:
# Number of filings matching the search criteria:
#  1565

# %%
print("Number of filings returned in this response:\n", len(response["filings"]))
# Out:
# Number of filings returned in this response:
#  50

# %%
import pandas as pd

metadata = pd.DataFrame.from_records(response["filings"])

print("Filing metadata objects converted to a DataFrame:")
metadata.head(3)
# Out:
# Filing metadata objects converted to a DataFrame:
#   ticker formType           accessionNo      cik        companyNameLong  \
# 0   TSLA      8-K  0001628280-24-041816  1318605    Tesla, Inc. (Filer)
# 1   TSLA        4  0001771340-24-000004  1318605   Tesla, Inc. (Issuer)
# 2   TSLA      144  0001950047-24-007342  1318605  Tesla, Inc. (Subject)
#
#    companyName                                linkToFilingDetails  \
# 0  Tesla, Inc.  https://www.sec.gov/Archives/edgar/data/131860...
# 1  Tesla, Inc.  https://www.sec.gov/Archives/edgar/data/131860...
# 2  Tesla, Inc.  https://www.sec.gov/Archives/edgar/data/131860...
#
#                                          description  \
# 0    Form 8-K - Current report - Item 2.02 Item 9.01
# 1  Form 4 - Statement of changes in beneficial ow...
# 2   Form 144 - Report of proposed sale of securities
#
#                                            linkToTxt  \
# 0  https://www.sec.gov/Archives/edgar/data/131860...
# 1  https://www.sec.gov/Archives/edgar/data/131860...
# 2  https://www.sec.gov/Archives/edgar/data/131860...
#
#                      filedAt  \
# 0  2024-10-02T09:06:34-04:00
# 1  2024-09-25T19:48:42-04:00
# 2  2024-09-23T16:27:57-04:00
#
#                                  documentFormatFiles periodOfReport  \
# 0  [{'sequence': '1', 'size': '34449', 'documentU...     2024-10-02
# 1  [{'sequence': '1', 'size': ' ', 'documentUrl':...     2024-09-23
# 2  [{'sequence': '1', 'size': ' ', 'documentUrl':...            NaN
#
#                                             entities  \
# 0  [{'fiscalYearEnd': '1231', 'stateOfIncorporati...
# 1  [{'fiscalYearEnd': '1231', 'stateOfIncorporati...
# 2  [{'fiscalYearEnd': '1231', 'stateOfIncorporati...
#
#                                  id seriesAndClassesContractsInformation  \
# 0  347fb19c073dc3f3e8be14aeec9d026c                                   []
# 1  e61d1cf43894398a94c4094bcaf71052                                   []
# 2  4e9e5cbfa0992bf5306f62d530b35d82                                   []
#
#                                                items  \
# 0  [Item 2.02: Results of Operations and Financia...
# 1                                                NaN
# 2                                                NaN
#
#                                           linkToHtml linkToXbrl  \
# 0  https://www.sec.gov/Archives/edgar/data/131860...
# 1  https://www.sec.gov/Archives/edgar/data/131860...
# 2  https://www.sec.gov/Archives/edgar/data/131860...
#
#                                            dataFiles effectivenessDate
# 0  [{'sequence': '3', 'size': '2509', 'documentUr...               NaN
# 1                                                 []               NaN
# 2                                                 []               NaN

# %%
available_fields = metadata.columns

print("Available filing metadata fields for this response:")
list(available_fields)
# Out:
# Available filing metadata fields for this response:
# ['ticker',
#  'formType',
#  'accessionNo',
#  'cik',
#  'companyNameLong',
#  'companyName',
#  'linkToFilingDetails',
#  'description',
#  'linkToTxt',
#  'filedAt',
#  'documentFormatFiles',
#  'periodOfReport',
#  'entities',
#  'id',
#  'seriesAndClassesContractsInformation',
#  'items',
#  'linkToHtml',
#  'linkToXbrl',
#  'dataFiles',
#  'effectivenessDate']
